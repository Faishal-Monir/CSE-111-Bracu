# %% [markdown]
# #*ASSIGNMENT-3*

# %%
#task-1
class Calculator:
    def __init__(self,var1,var2,var3):
        self.first=var1
        self.operator=var2
        self.second=var3
        
        print("Let’s Calculate!")
        print("Value 1:",var1)
        print("Operator:",var2)
        print("Value 2:",var3)
        
        if self.operator=="+":
            self.add()
        elif self.operator=="-":
            self.subtract()
        elif self.operator=="*":
            self.multiply()
        elif self.operator=="/":
            self.divide()
        else:
            print("Wrong input!!")
            
        
            
    def add(self):
        print("Result:",(self.first+self.second))
    def subtract(self):
        print("Result:",(self.first-self.second))
    def multiply(self):
        print("Result:",(self.first*self.second))
    def divide(self):
        print("Result:",(self.first/self.second))

var2=input("Enter operation:")
var1=int(input("Enter first Number:"))
var3=int(input("Enter second Number:"))
show=Calculator(var1,var2,var3)
# Out:
# Enter operation:+
# Enter first Number:10
# Enter second Number:10
# Let’s Calculate!
# Value 1: 10
# Operator: +
# Value 2: 10
# Result: 20

# %%
#TASK-2
class Course:
    def __init__(self,course,fact,sec):
        self.name=course
        self.faculty=fact
        self.section=sec
    def detail(self):
        print(self.name,"-",self.faculty,"-",self.section)
#__________________________________________________________________________________________________
c1 = Course("CSE110", "TBA", 8)
c1.detail()
print("===============")
c2 = Course("CSE111", "TBA", 9)
c2.detail()
# Out:
# CSE110 - TBA - 8
# ===============
# CSE111 - TBA - 9

# %%
#TASK-3
class Patient:
    def __init__(self,nam,age,weight,height):
        self.name=nam
        self.age=age
        self.weight=weight
        self.height=height
    def printDetails(self):
        self.height=self.height/100
        calculate=(self.weight/(self.height)**2)
        print("Name:",self.name)
        print("Age:",self.age)
        print("Weight:",self.weight)
        print("Height:",self.height)
        print("BMI:",calculate)
        
        
    
#_____________________________________________________________________________
        
p1 = Patient("A", 55, 63.0, 158.0)
p1.printDetails()
print("====================")
p2 = Patient("B", 53, 61.0, 149.0)
p2.printDetails()
# Out:
# Name: A
# Age: 55
# Weight: 63.0
# Height: 1.58
# BMI: 25.236340330075304
# ====================
# Name: B
# Age: 53
# Weight: 61.0
# Height: 1.49
# BMI: 27.476239809017613

# %%
#TASK-4
class Vehicle:
    def __init__(self):
        self.x=0
        self.y=0
    def print_position(self):
        print((self.x,self.y))
    def moveRight(self):
        self.x+=1
    def moveLeft(self):
        self.x-=1
    def moveUp(self):
        self.y+=1
    def moveDown(self):
        self.y-=1       
#____________________________________________________
       
car = Vehicle()
car.print_position()
car.moveUp()
car.print_position()
car.moveLeft()
car.print_position()
car.moveDown()
car.print_position()
car.moveRight()
# Out:
# (0, 0)
# (0, 1)
# (-1, 1)
# (-1, 0)

# %%
#TASK-5
class Shape:
    def __init__(self,var1,height,width):
        self.name=var1
        self.lenght=height
        self.width=width
    def area(self):
        if self.name=="Triangle":
            print("Area:",(0.5*self.lenght*self.width))
        elif self.name=="Square":
            print("Area:",(self.lenght*self.width))
        elif self.name=="Rhombus":
            print("Area:",(self.lenght*self.width)/2)
        elif self.name=="Rectangle":
            print("Area:",(self.lenght*self.width))
        else:
            print("Area:Shape unknown")
#____________________________________________________________________________________
        
triangle = Shape("Triangle",10,25)
triangle.area()
print("==========================")
square = Shape("Square",10,10)
square.area()
print("==========================")
rhombus = Shape("Rhombus",18,25)
rhombus.area()
print("==========================")
rectangle = Shape("Rectangle",15,30)
rectangle.area()
print("==========================")
trapezium = Shape("Trapezium",15,30)
trapezium.area()
# Out:
# Area: 125.0
# ==========================
# Area: 100
# ==========================
# Area: 225.0
# ==========================
# Area: 450
# ==========================
# Area:Shape unknown

# %%
#TASK-6
class Calculator:
    def __init__(self):
        print("Calculator is ready!")
        self.final=0
        self.first=None
        self.second=None
        self.operator=None
        
        
    def calculate(self,firstnumber,secondnumber,operator):
        self.first=firstnumber
        self.second=secondnumber
        self.operator=operator
        
        if operator=="+":
            self.final=firstnumber+secondnumber
            return self.final
        elif operator=="-":
            self.final=firstnumber-secondnumber
            return self.final
        elif operator=="*":
            self.final=firstnumber*secondnumber
            return self.final
        elif operator=="/":
            self.final=firstnumber/secondnumber
            return self.final
            
            
    def showCalculation(self):
        print(self.first,self.operator,self.second,"=",self.final)
        
        
#_______________________________________________________
c1 = Calculator()
print("==================")
val = c1.calculate(10, 20, '+')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 10, '-')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 5, '*')
print("Returned value:", val)
c1.showCalculation()
print("==================")
val = c1.calculate(val, 16, '/')
print("Returned value:", val)
c1.showCalculation()

#output
#'''Calculator is ready!
#==================
#Returned value: 30
#10 + 20 = 30
#==================
#Returned value: 20
#30 - 10 = 20
#==================
#Returned value: 100
#20 * 5 = 100
#==================
#Returned value: 6.25
#100 / 16 = 6.25'''
# Out:
# Calculator is ready!
# ==================
# Returned value: 30
# 10 + 20 = 30
# ==================
# Returned value: 20
# 30 - 10 = 20
# ==================
# Returned value: 100
# 20 * 5 = 100
# ==================
# Returned value: 6.25
# 100 / 16 = 6.25

# %%
#TASK-7
class Student:
    def __init__(self,name,identity,dep,cg):
        self.name=name
        self.id=identity
        self.department=dep
        self.cgpa=cg
    def calculate_CGPA(self):
        counter=0
        store=0
        for i in self.cgpa:
            store+=(3*i)
            counter+=3
        self.cgpa=(store/counter)
        counter=0
        store=0
    def print_details(self):
        print("Name:",self.name,",","ID:",self.id)
        print("Department:",self.department)
        print("CGPA:",self.cgpa)
        
        if self.cgpa>=3.80:
            print("Your academic standing is 'Highest Distinction'")
        elif self.cgpa>=3.65:
            print("Your academic standing is  'High Distinction'")
        elif self.cgpa>=3.50:
            print("Your academic standing is ' Distinction'")
        elif self.cgpa>=2.00:
            print("Your academic standing is 'Satisfactory'")
        elif self.cgpa<2.00:
            print("Sorry, you cannot graduate")
        

#_________________________________________________________________
s1 = Student('Dora', '15995599','CSE', [4,3.7,3.7,4])
s1.calculate_CGPA()
print("==========================")
s1.print_details()
print("==========================")
s2 = Student('Pingu', '12312322', 'EEE', [1.7,1.3,1.3,1.3,1])
s2.calculate_CGPA()
print("==========================")
s2.print_details()
print("==========================")
s3 = Student('Bob', '13311331', 'CSE', [2,3,3,3.7,2.7,2.7])
s3.calculate_CGPA()
print("==========================")
s3.print_details()
#__________________________________
#==========================
#Name: Dora, ID: 15995599
#Department: CSE
#CGPA: 3.85
#Your academic standing is 'Highest
#Distinction'
#==========================
#==========================
#Name: Pingu, ID: 12312322
#Department: CSE
#CGPA: 1.32
#Sorry, you cannot graduate
#==========================
#==========================
#Name: Bob, ID: 13311331
#Department: CSE
#CGPA: 2.85
#Your academic standing is 'Satisfactory'
# Out:
# ==========================
# Name: Dora , ID: 15995599
# Department: CSE
# CGPA: 3.85
# Your academic standing is 'Highest Distinction'
# ==========================
# ==========================
# Name: Pingu , ID: 12312322
# Department: EEE
# CGPA: 1.32
# Sorry, you cannot graduate
# ==========================
# ==========================
# Name: Bob , ID: 13311331
# Department: CSE
# CGPA: 2.85
# Your academic standing is 'Satisfactory'

# %%
#TASK-8
class Shinobi:
    def __init__(self,name,rank):
        self.name=name
        self.rank=rank
        self.salary=0
        self.mission=0
    def changeRank(self,rank):
        self.rank=rank
               
    def calSalary(self,var1):
        self.mission=var1
        if self.rank=="Genin":
            self.salary+=(self.mission*50)
        elif self.rank=="Chunin":
            self.salary+=(self.mission*100)
        else:
            self.salary+=(self.mission*500)

    def printInfo(self):
        print("Name:",self.name)
        print("Rank:",self.rank)
        print("Number of mission:",self.mission)
        print("Salary:",self.salary)
#__________________________________________________
naruto = Shinobi("Naruto", "Genin")
naruto.calSalary(5)
naruto.printInfo()
print('====================')
shikamaru = Shinobi('Shikamaru', "Genin")
shikamaru.printInfo()
shikamaru.changeRank("Chunin")
shikamaru.calSalary(10)
shikamaru.printInfo()
print('====================')
neiji = Shinobi("Neiji", "Jonin")
neiji.calSalary(5)
neiji.printInfo()
#____________________________________
#OUTPUT:
#Name: Naruto
#Rank: Genin
#Number of mission: 5
#Salary: 250
#====================
#Name: Shikamaru
#Rank: Genin
#Number of mission: 0
#Salary: 0
#Name: Shikamaru
#Rank: Chunin
#Number of mission: 10
#Salary: 1000
#====================
#Name: Neiji
#Rank: Jonin
#Number of mission: 5
#Salary: 2500
# Out:
# Name: Naruto
# Rank: Genin
# Number of mission: 5
# Salary: 250
# ====================
# Name: Shikamaru
# Rank: Genin
# Number of mission: 0
# Salary: 0
# Name: Shikamaru
# Rank: Chunin
# Number of mission: 10
# Salary: 1000
# ====================
# Name: Neiji
# Rank: Jonin
# Number of mission: 5
# Salary: 2500

# %%
#TASK-9
class Programmer:
    def __init__(self,name,lan,time):
        print("Horray! A new programmer is born")
        self.name=name
        self.language=lan
        self.year=time
    def addExp(self,time):
        self.year+=time
        print("Updating experience of",self.name)
    def printDetails(self):
        print("Name:",self.name)
        print("Language:",self.language)
        print("Experience:",self.year,"years")
         
#____________________________________________________________________
p1 = Programmer("Ethen Hunt", "Java", 10)
p1.printDetails()
print('--------------------------')
p2 = Programmer("James Bond", "C++", 7)
p2.printDetails()
print('--------------------------')
p3 = Programmer("Jon Snow", "Python", 4)
p3.printDetails()
p3.addExp(5)
p3.printDetails() 
#___________________________________________________________________________
#Horray! A new programmer is born
#Name: Ethen Hunt
#Language: Java
#Experience: 10 years.
#--------------------------
#Horray! A new programmer is born
#Name: James Bond
#Language: C++
#Experience: 7 years.
#--------------------------
#Horray! A new programmer is born
#Name: Jon Snow
#Language: Python
#Experience: 4 years.
#Updating experience of Jon Snow
#Name: Jon Snow
#Language: Python
#Experience: 9 years.
# Out:
# Horray! A new programmer is born
# Name: Ethen Hunt
# Language: Java
# Experience: 10 years
# --------------------------
# Horray! A new programmer is born
# Name: James Bond
# Language: C++
# Experience: 7 years
# --------------------------
# Horray! A new programmer is born
# Name: Jon Snow
# Language: Python
# Experience: 4 years
# Updating experience of Jon Snow
# Name: Jon Snow
# Language: Python
# Experience: 9 years

# %%
#TASK-10
class UberEats:
    def __init__(self,nam,mob,address):
        self.name=nam
        self.mobile=mob
        self.address=address
        self.order=None
        self.amount=None
        print(self.name,", welcome to UberEats!")
    def add_items(self,var1,var2,var3,var4):
        self.order={var1:var3,var2:var4}
        self.amount=var3+var4
    def print_order_detail(self):
        return f"Name:{self.name}, Phone:{self.mobile}, Address:{self.address}\nOrders:{self.order}\nTotal Paid Amount:{self.amount}"

#________________________________________________________________________
order1 = UberEats("Shakib", "01719658xxx", "Mohakhali")
print("=========================")
order1.add_items("Burger", "Coca Cola", 220, 50)
print("=========================")
print(order1.print_order_detail())
print("=========================")
order2 = UberEats ("Siam", "01719659xxx", "Uttara")
print("=========================")
order2.add_items("Pineapple", "Dairy Milk", 80, 70)
print("=========================")
print(order2.print_order_detail())
#__________________________________________________________________________
#Shakib, welcome to UberEats!
#=========================
#=========================
#User details: Name: Shakib, Phone:
#01719658xxx, Address: Mohakhali
#Orders: {'Burger': 220, 'Coca Cola': 50}
#Total Paid Amount: 270
#=========================
#Siam, welcome to UberEats!
#=========================
#=========================
#User details: Name: Siam, Phone:
#01719659xxx, Address: Uttara
#Orders: {'Pineapple': 80, 'Dairy Milk': 70}
#Total Paid Amount: 150
# Out:
# Shakib , welcome to UberEats!
# =========================
# =========================
# Name:Shakib, Phone:01719658xxx, Address:Mohakhali
# Orders:{'Burger': 220, 'Coca Cola': 50}
# Total Paid Amount:270
# =========================
# Siam , welcome to UberEats!
# =========================
# =========================
# Name:Siam, Phone:01719659xxx, Address:Uttara
# Orders:{'Pineapple': 80, 'Dairy Milk': 70}
# Total Paid Amount:150

# %%
#TASK-11
class Spotify:
    def __init__(self,data):
        print("Welcome to Spotify!")
        self.music=data
    def playing_number(self,num):
        if len(self.music)<num:
            return f"{num} number song not found. Your playlist has {len(self.music)} songs only."
        else:
            return f"##########################\nPlaying {num} number song for you\nSong name:{self.music[num-1]} "
        
    def add_to_playlist(self,name):
        self.music.append(name)
        
#______________________________________________
user1 = Spotify(["See You Again", "Uptown Funk", "Hello"])
print("=========================")
print(user1.playing_number(4))
user1.add_to_playlist("Dusk Till Dawn")
print(user1.playing_number(3))
print(user1.playing_number(4))
#____________________________________________________
#Welcome to Spotify!
#=========================
#4 number song not found. Your playlist
#has 3 songs only.
##########################
#Playing 3 number song for you
#Song name: Hello
##########################
#Playing 4 number song for you
#Song name: Dusk Till Dawn
# Out:
# Welcome to Spotify!
# =========================
# 4 number song not found. Your playlist has 3 songs only.
# ##########################
# Playing 3 number song for you
# Song name:Hello
# ##########################
# Playing 4 number song for you
# Song name:Dusk Till Dawn
